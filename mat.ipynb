# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = np.arange(0,20,0.1)
# plt.axis([0,6,0,20])
plt.plot(a,np.cos(a),label="cos")
plt.ylabel("v")
plt.plot(a,np.sin(a),label="sin")
plt.xlabel("x")
plt.title("xiajierhuanljuan")
plt.grid(True)
plt.legend()
plt.show()
print("hello world")

# %%
import torch.nn as nn
import  torch

a = torch.arange(0,10,0.5).view(20,1)
y = a*2 + 2 + torch.randn(20,1)
plt.scatter(a.squeeze().numpy(),y.squeeze().numpy())
