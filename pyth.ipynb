# %%
import torch
import numpy as np
import d2l

# %%
l1 = np.arange(0,10,1.5)
t1 = torch.tensor([1,2,3,4])
t2 = torch.tensor([1,2,3,4])
q = torch.eye(4,4)
d = torch.diag(torch.Tensor([1,2,3,4]))
# q = q.reshape(2,8)
# t1.add_(t2)
# torch.cumsum(q,1)
qq = torch.linspace(0,100,25).view(5,5)
t1 = torch.Tensor([1,0,0,0,0])

# torch.mv(qq.t(),t1)
torch.cat((t1,t2))
qq.nelement()
# Out:
# 25

# %%
#定义叶子节点张量x，形状为1x2
x= torch.tensor([[2, 3]], dtype=torch.float, requires_grad=True)
#初始化Jacobian矩阵
J= torch.zeros(2 ,2)
#初始化目标张量，形状为1x2
y = torch.zeros(1, 2)
#定义y与x之间的映射关系： #y1=x1**2+3*x2，y2=x2**2+2*x1
y[0, 0] = x[0, 0] ** 2 + 3 * x[0 ,1]
y[0, 1] = x[0, 1] ** 2 + 2 * x[0, 0]
y.backward(torch.Tensor([[0, 1]]),retain_graph=True)
c = torch.arange(4).view(2,2)
c.mm(torch.tensor([[1],[1]]))a
# Out:
# tensor([[1],
#         [5]])

# %%
from d2l import torch as d2l
import torch
x = torch.arange(-8.0, 8.0, 0.1, requires_grad=True)
y = torch.relu(x)
d2l.plot(x.detach(), y.detach(), 'x', 'relu(x)', figsize=(5, 2.5))
